# %%
#네이버 블로그 검색
id = 'sUD9HK3o12p2_mhTK3PT'
key = 'cJJ9z7xQyT'
import os
import sys
import urllib.request
import json
client_id = id
client_secret = key
keyword= input('검색할 단어>>>')
encText = urllib.parse.quote(keyword)
data = []
for i in range(1,1001,100):
    url = f"https://openapi.naver.com/v1/search/blog?&display=100&start={i}&query=" + encText # json 결과
    request = urllib.request.Request(url)
    request.add_header("X-Naver-Client-Id",client_id)
    request.add_header("X-Naver-Client-Secret",client_secret)
    response = urllib.request.urlopen(request)
    rescode = response.getcode()
    if(rescode==200):
        response_body = response.read()
        # print(response_body.decode('utf-8'))
        d = json.loads(response_body)
        data.extend(d['items'])
    else:
        print("Error Code:" + rescode)

# %%
len(data)
# Out:
# 1000

# %%
type(response_body)
# Out:
# bytes

# %%
response_body["lastBuildDate"]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_12856/1576984888.py in <module>
# ----> 1 response_body["lastBuildDate"]
#
# TypeError: byte indices must be integers or slices, not str

# %%
import json
data = json.loads(response_body)

# %%
type(data)
# Out:
# dict

# %%
data["lastBuildDate"]
# Out:
# 'Mon, 14 Mar 2022 09:43:12 +0900'

# %%
data
# Out:
# {'lastBuildDate': 'Mon, 14 Mar 2022 09:43:12 +0900',
#  'total': 774405,
#  'start': 1,
#  'display': 100,
#  'items': [{'title': '<b>봄비</b>에 찾은 &quot;전남 도립미술관&quot;.......',
#    'link': 'https://blog.naver.com/equsepark?Redirect=Log&logNo=222671575915',
#    'description': '찾아봐야 겠네요 모처럼 내리는 <b>봄비</b>에 매화꽃도 이슬을 머금었네요...... 2022년 3월 13일 가뭄에 <b>봄비</b>가 단비가 되어 내리던 휴일에 초록현서랑 광양읍에 위치한 전남 도립 미술관에서 잘 보고 왔네요.......',
#    'bloggername': '에쿠스박',
#    'bloggerlink': 'https://blog.naver.com/equsepark',
#    'postdate': '20220313'},
#   {'title': '<b>봄비</b> 오는 날, 강릉 봄소식',
#    'link': 'https://blog.naver.com/uock?Redirect=Log&logNo=222671543883',
#    'description': '기다리고 기다리던 <b>봄비</b>가 내렸습니다. 넉넉하지는 않지만, 그래도 걱정스러웠던 울진 삼척 지역의... 작은 전구를 매달아 둔 듯 물방울이 반짝이더군요. <b>봄비</b> 속 반가운 봄맞이를 다녀왔네요. 20220. 3. 13.',
#    'bloggername': '유쾌한 사진공작소',
#    'bloggerlink': 'https://blog.naver.com/uock',
#    'postdate': '20220313'},
#   {'title': '<b>봄비</b>',
# ...

# %%
#네이버 뉴스 검색

id = 'sUD9HK3o12p2_mhTK3PT'
key = 'cJJ9z7xQyT'
import os
import sys
import urllib.request
import json
client_id = id
client_secret = key
keyword= input('검색할 단어>>>')
encText = urllib.parse.quote(keyword)
data = []
for i in range(1,1001,100):
    url = f"https://openapi.naver.com/v1/search/news?&display=100&start={i}&query=" + encText # json 결과
    request = urllib.request.Request(url)
    request.add_header("X-Naver-Client-Id",client_id)
    request.add_header("X-Naver-Client-Secret",client_secret)
    response = urllib.request.urlopen(request)
    rescode = response.getcode()
    if(rescode==200):
        response_body = response.read()
        # print(response_body.decode('utf-8'))
        d = json.loads(response_body)
        data.extend(d['items'])
    else:
        print("Error Code:" + rescode)

# %%
data
# Out:
# [{'title': '오늘도 촉촉한 <b>봄비</b>…서쪽 중심 짙은 안개 주의',
#   'originallink': 'http://www.obsnews.co.kr/news/articleView.html?idxno=1346432',
#   'link': 'http://www.obsnews.co.kr/news/articleView.html?idxno=1346432',
#   'description': '어제에 이어 촉촉한 <b>봄비</b>가 내리겠습니다. 비는 아침부터\xa0중부서해안을 시작으로 낮까지 전국에 확대되겠고요. 저녁에 대부분 그치겠습니다. 예상되는 비의 양은 중부와 경북북부에 최대 15mm, 그 밖의 지역은 5mm... ',
#   'pubDate': 'Mon, 14 Mar 2022 10:02:00 +0900'},
#  {'title': "[이번주 날씨] 대체로 포근 '완연한 봄'…목요일부터 전국에 비",
#   'originallink': 'http://www.newsquest.co.kr/news/articleView.html?idxno=94286',
#   'link': 'http://www.newsquest.co.kr/news/articleView.html?idxno=94286',
#   'description': '일요일이었던 지난 13일 서울 강남구 봉은사에서 <b>봄비</b>를 머금은 홍매화가 꽃망울을 터트리고 있다. [사진=연합뉴스] 이번 주는 전국이 대체로 맑은 가운데 아침기온도 대부분 영상권에 머무르는 등 포근한 날씨가... ',
#   'pubDate': 'Mon, 14 Mar 2022 09:48:00 +0900'},
#  {'title': '[날씨] 전국에 <b>봄비</b>‥목요일~금요일 또 비',
#   'originallink': 'https://imnews.imbc.com/replay/2022/nw930/article/6349878_35736.html',
# ...

# %%
#네이버 책 검색 

id = 'sUD9HK3o12p2_mhTK3PT'
key = 'cJJ9z7xQyT'
import os
import sys
import urllib.request
import json
client_id = id
client_secret = key
keyword= input('검색할 단어>>>')
encText = urllib.parse.quote(keyword)
data = []
for i in range(1,1001,100):
    url = f"https://openapi.naver.com/v1/search/book?&display=100&start={i}&query=" + encText # json 결과
    request = urllib.request.Request(url)
    request.add_header("X-Naver-Client-Id",client_id)
    request.add_header("X-Naver-Client-Secret",client_secret)
    response = urllib.request.urlopen(request)
    rescode = response.getcode()
    if(rescode==200):
        response_body = response.read()
        # print(response_body.decode('utf-8'))
        d = json.loads(response_body)
        data.extend(d['items'])
    else:
        print("Error Code:" + rescode)

# %%
data
# Out:
# [{'title': '<b>정의</b>란 무엇인가 (한국 200만 부 돌파, 37개국에서 출간된 세계적 베스트셀러,새로운 시대, 새로운 <b>정의</b>)',
#   'link': 'http://book.naver.com/bookdb/book_detail.php?bid=8374306',
#   'image': 'https://bookthumb-phinf.pstatic.net/cover/083/743/08374306.jpg?type=m1&udate=20220225',
#   'author': '마이클 샌델',
#   'price': '15000',
#   'discount': '13500',
#   'publisher': '와이즈베리',
#   'pubdate': '20141120',
#   'isbn': '8937834790 9788937834790',
#   'description': '<b>정의</b>론의 세계적 석학, 마이클 샌델 교수의 생기 넘치는 강의실로 초대합니다!『<b>정의</b>란 무엇인가』는 27세에 최연소 하버드대학교 교수가 되었고, 존 롤스의 <b>정의</b>론을 비판한 《자유주의와 <b>정의</b>의 한계》를 발표하면서 세계적 학자로 인정받은 정치 철학가 마이클 샌델의 대표작이다. 샌델 교수가 실제로... '},
#  {'title': '10대를 위한 JUSTICE <b>정의</b>란 무엇인가 (하버드대 마이클 샌델 교수의 <b>정의</b> 수업)',
#   'link': 'http://book.naver.com/bookdb/book_detail.php?bid=8402755',
#   'image': 'https://bookthumb-phinf.pstatic.net/cover/084/027/08402755.jpg?type=m1&udate=20220112',
#   'author': '마이클 샌델|신현주',
#   'price': '12000',
#   'discount': '10800',
# ...

# %%
#네이버 백과사전 검색

id = 'sUD9HK3o12p2_mhTK3PT'
key = 'cJJ9z7xQyT'
import os
import sys
import urllib.request
import json
client_id = id
client_secret = key
keyword= input('검색할 단어>>>')
encText = urllib.parse.quote(keyword)
data = []
for i in range(1,1001,100):
    url = f"https://openapi.naver.com/v1/search/encyc?&display=100&start={i}&query=" + encText # json 결과
    request = urllib.request.Request(url)
    request.add_header("X-Naver-Client-Id",client_id)
    request.add_header("X-Naver-Client-Secret",client_secret)
    response = urllib.request.urlopen(request)
    rescode = response.getcode()
    if(rescode==200):
        response_body = response.read()
        # print(response_body.decode('utf-8'))
        d = json.loads(response_body)
        data.extend(d['items'])
    else:
        print("Error Code:" + rescode)

# %%
data
# Out:
# [{'title': '<b>가다</b>',
#   'link': 'https://terms.naver.com/entry.naver?docId=6076459&cid=67350&categoryId=67350',
#   'description': '[재료 및 시공] ① → 거더(＝). ② → 큰보(＝). 참고 : 건축용어대사전, 기문당',
#   'thumbnail': ''},
#  {'title': '<b>가다</b>',
#   'link': 'https://terms.naver.com/entry.naver?docId=2798502&cid=55598&categoryId=55598',
#   'description': '① 한곳으로부터 다른 곳으로 자리를 옮기어 두다. *요처에 ∼. ② 특정한 목적을 향해 움직이다. *잡으러 ∼.',
#   'thumbnail': ''},
#  {'title': '<b>가다</b>',
#   'link': 'https://ko.wikipedia.org/wiki/%EA%B0%80%EB%8B%A4',
#   'description': '<b>가다</b> ( 산스크리트어: गदा )는 인도 아대륙에서 사용되었던 철퇴의 일종이다. 힌두교의 삼주신 중 한 명인 비슈누는 카우모다키라는 이름의 <b>가다</b>를 지니고 있으며 마하바라타의 주요 등장인물 중 한 명인... ',
#   'thumbnail': ''},
#  {'title': '동음이의어와 다의어의 예',
#   'link': 'https://terms.naver.com/entry.naver?docId=3559662&cid=58583&categoryId=58729',
#   'description': ' 동음이의어와 다의어의 예를 알아본다. [ 1. <b>가다</b>] [ 1) <b>가다</b>1(자동사)] ① 이곳에서 저곳으로 옮아 움직이다. (예) 학교에 <b>가다</b>. ② (있던 자리를) 떠나다. (예) 나 보기가 역겨워 가실 때에는 말없이 고이 보내... ',
# ...

# %%
#성인검색어 판별
id = 'sUD9HK3o12p2_mhTK3PT'
key = 'cJJ9z7xQyT'
import os
import sys
import urllib.request
import json
client_id = id
client_secret = key
keyword= input('검색할 단어>>>')
encText = urllib.parse.quote(keyword)
url = f"https://openapi.naver.com/v1/search/adult?query=" + encText # json 결과
request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)
response = urllib.request.urlopen(request)
rescode = response.getcode()
if(rescode==200):
    response_body = response.read()
    # print(response_body.decode('utf-8'))
    d = int(json.loads(response_body)['adult']) #loads s는 파이썬형태로 불러올때
    if d == 0:
        print('성인검색어가 없습니다.')
    else:
        print('성인검색어가 있습니다.')
else:
    print("Error Code:" + rescode)
# Out:
# 검색할 단어>>> ㅇ
# 성인검색어가 없습니다.

# %%
#오타변환
id = 'sUD9HK3o12p2_mhTK3PT'
key = 'cJJ9z7xQyT'
import os
import sys
import urllib.request
import json
client_id = id
client_secret = key
keyword= input('검색할 단어>>>')
encText = urllib.parse.quote(keyword)
url = f"https://openapi.naver.com/v1/search/errata?query=" + encText # json 결과
request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)
response = urllib.request.urlopen(request)
rescode = response.getcode()
if(rescode==200):
    response_body = response.read()
    # print(response_body.decode('utf-8'))
    d = json.loads(response_body)['errata'] #loads s는 파이썬형태로 불러올때
    if len(d) > 0:
        print(f'오타가 있어 {d}(으)로 변환하여 검색되었습니다.')
    else:
        pass
else:
    print("Error Code:" + rescode)
# Out:
# 검색할 단어>>> 지금 잠간편의점갓다올수있어?

# %%
#카카오 주소 검색
REST_API_KEY = '3a211f9eba413113b5fd2f40fef1bd61'

# %% [raw]
# curl -v -X GET
# "https://dapi.kakao.com/v2/local/search/address.json" \
#   -H "Authorization: KakaoAK ${REST_API_KEY}" \
#   --data-urlencode "query=전북 삼성동 100"

# %%
import requests
import json
keyword = input('검색할 주소 >>> ')
url = f"https://dapi.kakao.com/v2/local/search/address.json?query={keyword}"
headers = {'Authorization': f'KakaoAK {REST_API_KEY}'}
res = requests.get(url,headers=headers)
res = res.json()
res
# Out:
# 검색할 주소 >>>  전북 삼성동 100
# {'documents': [{'address': {'address_name': '전북 익산시 부송동 100',
#     'b_code': '4514013400',
#     'h_code': '4514069000',
#     'main_address_no': '100',
#     'mountain_yn': 'N',
#     'region_1depth_name': '전북',
#     'region_2depth_name': '익산시',
#     'region_3depth_h_name': '삼성동',
#     'region_3depth_name': '부송동',
#     'sub_address_no': '',
#     'x': '126.99597495347',
#     'y': '35.9766482774579'},
#    'address_name': '전북 익산시 부송동 100',
#    'address_type': 'REGION_ADDR',
#    'road_address': None,
#    'x': '126.99597495347',
#    'y': '35.9766482774579'},
#   {'address': {'address_name': '전북 익산시 임상동 100',
#     'b_code': '4514013200',
#     'h_code': '4514069000',
#     'main_address_no': '100',
#     'mountain_yn': 'N',
#     'region_1depth_name': '전북',
#     'region_2depth_name': '익산시',
#     'region_3depth_h_name': '삼성동',
#     'region_3depth_name': '임상동',
#     'sub_address_no': '',
#     'x': '126.980268573424',
# ...

# %% [raw]
# curl -v -X GET
# "https://dapi.kakao.com/v2/local/geo/coord2regioncode.json?x=127.1086228&y=37.4012191" \
#   -H "Authorization: KakaoAK ${REST_API_KEY}"

# %%
REST_API_KEY = '3a211f9eba413113b5fd2f40fef1bd61'
import requests
import json
x = input('x좌표값을 넣으세요>>>')
y = input('y좌표값을 넣으세요>>>')
url = f"https://dapi.kakao.com/v2/local/geo/coord2regioncode.json?x={x}&y={y}"
headers = {'Authorization': f'KakaoAK {REST_API_KEY}'}
res = requests.get(url,headers=headers)
res = res.json()
res
# Out:
# x좌표값을 넣으세요>>> 129.0899126038302
# y좌표값을 넣으세요>>> 35.11667480338896
# {'meta': {'total_count': 2},
#  'documents': [{'region_type': 'B',
#    'code': '2629010800',
#    'address_name': '부산광역시 남구 용당동',
#    'region_1depth_name': '부산광역시',
#    'region_2depth_name': '남구',
#    'region_3depth_name': '용당동',
#    'region_4depth_name': '',
#    'x': 129.0950407144003,
#    'y': 35.11764987408262},
#   {'region_type': 'H',
#    'code': '2629061000',
#    'address_name': '부산광역시 남구 용당동',
#    'region_1depth_name': '부산광역시',
#    'region_2depth_name': '남구',
#    'region_3depth_name': '용당동',
#    'region_4depth_name': '',
#    'x': 129.0950407144003,
#    'y': 35.11764987408262}]}

# %% [raw]
# curl -v -X GET
# "https://dapi.kakao.com/v2/local/search/keyword.json?y=37.514322572335935&x=127.06283102249932&radius=20000" \
#   -H "Authorization: KakaoAK ${REST_API_KEY}" \
#   --data-urlencode "query=카카오프렌즈"

# %%
REST_API_KEY = '3a211f9eba413113b5fd2f40fef1bd61'
import requests
import json
query = input('검색할 단어>>>')
x = 129.0950407144003
y = 35.11764987408262
radius = input('반경(m)>>>')
category_group_code = input('''
대형마트 : MT1
편의점 : CS2
어린이집, 유치원 : PS3
학교 : SC4
학원 : AC5
주차장 : PK6
주유소, 충전소 : OL7
지하철역 : SW8
은행 : BK9
문화시설 : CT1
중개업소 : AG2
공공기관 : PO3
관광명소 : AT4
숙박 : AD5
음식점 : FD6
카페 : CE7
병원 : HP8
약국 : PM9
''')
url = f'''https://dapi.kakao.com/v2/local/search/keyword.json?query={query}&x={x}&y={y}
          &category_group_code={category_group_code}&radius={radius}'''
headers = {'Authorization': f'KakaoAK {REST_API_KEY}'}
res = requests.get(url,headers=headers)
res = res.json()
res
# Out:
# 검색할 단어>>> gs
# 반경(m)>>> 2000
#
# 대형마트 : MT1
# 편의점 : CS2
# 어린이집, 유치원 : PS3
# 학교 : SC4
# 학원 : AC5
# 주차장 : PK6
# 주유소, 충전소 : OL7
# 지하철역 : SW8
# 은행 : BK9
# 문화시설 : CT1
# 중개업소 : AG2
# 공공기관 : PO3
# 관광명소 : AT4
# 숙박 : AD5
# 음식점 : FD6
# 카페 : CE7
# 병원 : HP8
# 약국 : PM9
#  CS2
# {'documents': [{'address_name': '부산 남구 용당동 164-2',
#    'category_group_code': 'CS2',
#    'category_group_name': '편의점',
#    'category_name': '가정,생활 > 편의점 > GS25',
#    'distance': '428',
#    'id': '12294960',
#    'phone': '051-624-0812',
#    'place_name': 'GS25 신선대점',
#    'place_url': 'http://place.map.kakao.com/12294960',
#    'road_address_name': '부산 남구 신선로 309-1',
#    'x': '129.095486170113',
#    'y': '35.1138032263504'},
#   {'address_name': '부산 남구 용당동 454-22',
#    'category_group_code': 'CS2',
#    'category_group_name': '편의점',
#    'category_name': '가정,생활 > 편의점 > GS25',
#    'distance': '360',
#    'id': '18578418',
#    'phone': '051-628-5008',
#    'place_name': 'GS25 용당해군점',
# ...

# %% [raw]
# curl -v -X GET
# "https://dapi.kakao.com/v2/local/search/category.json?category\_group\_code=PM9&radius=20000" \
#   -H "Authorization: KakaoAK ${REST_API_KEY}"

# %%
REST_API_KEY = '3a211f9eba413113b5fd2f40fef1bd61'
import requests
import json
x = 129.0950407144003
y = 35.11764987408262
radius = input('반경(m)>>>')
category_group_code = input('''
대형마트 : MT1
편의점 : CS2
어린이집, 유치원 : PS3
학교 : SC4
학원 : AC5
주차장 : PK6
주유소, 충전소 : OL7
지하철역 : SW8
은행 : BK9
문화시설 : CT1
중개업소 : AG2
공공기관 : PO3
관광명소 : AT4
숙박 : AD5
음식점 : FD6
카페 : CE7
병원 : HP8
약국 : PM9
''')
url = f'''https://dapi.kakao.com/v2/local/search/category.json?x={x}&y={y}
          &category_group_code={category_group_code}&radius={radius}'''
headers = {'Authorization': f'KakaoAK {REST_API_KEY}'}
res = requests.get(url,headers=headers)
res = res.json()
res
# Out:
# 반경(m)>>> 2000
#
# 대형마트 : MT1
# 편의점 : CS2
# 어린이집, 유치원 : PS3
# 학교 : SC4
# 학원 : AC5
# 주차장 : PK6
# 주유소, 충전소 : OL7
# 지하철역 : SW8
# 은행 : BK9
# 문화시설 : CT1
# 중개업소 : AG2
# 공공기관 : PO3
# 관광명소 : AT4
# 숙박 : AD5
# 음식점 : FD6
# 카페 : CE7
# 병원 : HP8
# 약국 : PM9
#  CS2
# {'documents': [{'address_name': '부산 남구 용당동 454-22',
#    'category_group_code': 'CS2',
#    'category_group_name': '편의점',
#    'category_name': '가정,생활 > 편의점 > GS25',
#    'distance': '360',
#    'id': '18578418',
#    'phone': '051-628-5008',
#    'place_name': 'GS25 용당해군점',
#    'place_url': 'http://place.map.kakao.com/18578418',
#    'road_address_name': '부산 남구 신선로 393-9',
#    'x': '129.097233389959',
#    'y': '35.1203550715089'},
#   {'address_name': '부산 남구 용당동 164-2',
#    'category_group_code': 'CS2',
#    'category_group_name': '편의점',
#    'category_name': '가정,생활 > 편의점 > GS25',
#    'distance': '428',
#    'id': '12294960',
#    'phone': '051-624-0812',
#    'place_name': 'GS25 신선대점',
# ...

# %%
#영화진흥위원회
key = '026fef378b7f84ccf52ba8806c87f6ff'
date = '20220313'
url = f'''http://www.kobis.or.kr/kobisopenapi/webservice/rest/boxoffice/searchDailyBoxOfficeList.json?key={key}&targetDt={date}'''
res = requests.get(url)
print(res.json())
# Out:
# {'boxOfficeResult': {'boxofficeType': '일별 박스오피스', 'showRange': '20220313~20220313', 'dailyBoxOfficeList': [{'rnum': '1', 'rank': '1', 'rankInten': '0', 'rankOldAndNew': 'OLD', 'movieCd': '20190299', 'movieNm': '이상한 나라의 수학자', 'openDt': '2022-03-09', 'salesAmt': '604629280', 'salesShare': '42.6', 'salesInten': '51307650', 'salesChange': '9.3', 'salesAcc': '2345227040', 'audiCnt': '61979', 'audiInten': '5674', 'audiChange': '10.1', 'audiAcc': '246226', 'scrnCnt': '1310', 'showCnt': '5248'}, {'rnum': '2', 'rank': '2', 'rankInten': '0', 'rankOldAndNew': 'OLD', 'movieCd': '20212973', 'movieNm': '더 배트맨', 'openDt': '2022-03-01', 'salesAmt': '452014860', 'salesShare': '31.8', 'salesInten': '-63578060', 'salesChange': '-12.3', 'salesAcc': '7623442050', 'audiCnt': '42398', 'audiInten': '-5603', 'audiChange': '-11.7', 'audiAcc': '733821', 'scrnCnt': '1464', 'showCnt': '4029'}, {'rnum': '3', 'rank': '3', 'rankInten': '0', 'rankOldAndNew': 'OLD', 'movieCd': '20223278', 'movieNm': '극장판 주술회전 0', 'op
# ...

# %%
from hanspell import spell_checker
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_8460/2065568038.py in <module>
# ----> 1 from hanspell import spell_checker
#
# ModuleNotFoundError: No module named 'hanspell'

# %%
from hanspell import spell_checker
word = input()
result = spell_checker.check(f'{word}')
result.as_dict()  # dict로 출력
result
uese = []
for key, value in result.words.items():
    print(key)
# Out:
#  djaak qkQj?
# 엄마
# qkQj?

# %%
result
# Out:
# Checked(result=True, original='외안되', checked='왜 안돼', errors=1, words=OrderedDict([('왜', 1), ('안돼', 1)]), time=0.021442890167236328)

# %%
from hanspell import spell_checker
spell_checker.check([u'안녕 하세요.', u'저는 한국인 입니다.'])
# Out:
# [Checked(result=True, original='안녕 하세요.', checked='안녕하세요.', errors=1, words=OrderedDict([('안녕하세요.', 2)]), time=0.02144312858581543),
#  Checked(result=True, original='저는 한국인 입니다.', checked='저는 한국인입니다.', errors=1, words=OrderedDict([('저는', 0), ('한국인입니다.', 2)]), time=0.03225374221801758)]

# %%
for key, value in result.words.items():        
    print(key, value)
# Out:
# 안녕하세요. 2
# 저는 0
# 한국인입니다. 2
# 이 2
# 문장은 2
# 한글로 0
# 작성됐습니다. 1
